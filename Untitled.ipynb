# %%
conda install -c conda-forge spacy python -m
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\brand\anaconda3
#
#   added / updated specs:
#     - spacy
#
#
# The following NEW packages will be INSTALLED:
#
#   catalogue          conda-forge/win-64::catalogue-2.0.6-py38haa244fe_1
#   chardet            conda-forge/win-64::chardet-4.0.0-py38haa244fe_2
#   cymem              conda-forge/win-64::cymem-2.0.6-py38h885f38d_2
#   cython-blis        conda-forge/win-64::cython-blis-0.7.5-py38h6f4d8f0_1
#   idna               conda-forge/noarch::idna-3.1-pyhd3deb0d_0
#   langcodes          conda-forge/noarch::langcodes-3.3.0-pyhd8ed1ab_0
#   murmurhash         conda-forge/win-64::murmurhash-1.0.6-py38h885f38d_2
#   pathy              conda-forge/noarch::pathy-0.6.1-pyhd8ed1ab_0
#   preshed            conda-forge/win-64::preshed-3.0.6-py38h885f38d_1
#   pydantic           conda-forge/win-64::pydantic-1.8.2-py38h294d835_2
# ...

# %%
spacy download en_core_web_sm
# Out:
#   File "C:\Users\brand\AppData\Local\Temp/ipykernel_10948/1222985982.py", line 1
#     spacy download en_core_web_sm
#           ^
# SyntaxError: invalid syntax
